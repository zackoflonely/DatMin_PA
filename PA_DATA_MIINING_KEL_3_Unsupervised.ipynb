# %% [markdown]
# <a href="https://colab.research.google.com/github/zackoflonely/DatMin_PA/blob/main/PA_DATA_MIINING_KEL_3_Unsupervised.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #UnSupervised Learning

# %% [markdown]
# ## Bussiness Understanding

# %% [markdown]
# Data kualitas wine merupakan kumpulan kandungan yang dimiliki setiap wine. data ini digunakan untuk membantu bisnis lebih memahami preferensi dan citarasa pelanggan terhadap berbagai jenis wine yang dihasilkan. Data yang berisi kandungan dalam wine ini bisa digunakan untuk menentukan klaster kualitas setiap wine. Dengan begitu bisnis dapat menyesuaikan strategi pemasaran dan produksi wine mereka. Misalnya, bisnis dapat mengidentifikasi jenis wine yang paling diminati dan fokus untuk meningkatkan kualitas produksi pada jenis tersebut. Selain itu, dengan mengetahui preferensi pelanggan, bisnis dapat menyesuaikan harga wine, membuat promosi yang lebih tepat sasaran, dan meningkatkan kepuasan pelanggan. Dalam jangka panjang, analisis klaster kualitas wine ini dapat membantu bisnis dalam mempertahankan pangsa pasar dan meningkatkan keuntungan mereka.

# %% [markdown]
# ### Tujuan Analisis Dataset
# Tujuan dari menganalisis dataset ini untuk menyediakan produk wine yang berkualitas dan digemari khalayak ramai sehingga dapat membuat income yang besar untuk bar.

# %% [markdown]
# ## Data Understanding

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('https://raw.githubusercontent.com/zackoflonely/DatMin_PA/main/winequality-red.csv')

# %% [markdown]
# ### Describe Data
# Berikut merupakan isi keseluruhan dataset:

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
print("Berikut daftar kolom yang ada pada dataframe :")
for col in df.columns:
  print(col)
# Out:
# Berikut daftar kolom yang ada pada dataframe :
# fixed acidity
# volatile acidity
# citric acid
# residual sugar
# chlorides
# free sulfur dioxide
# total sulfur dioxide
# density
# pH
# sulphates
# alcohol
# quality

# %% [markdown]
# ### Penjelasan Kolom

# %% [markdown]
# Fixed Acidity: Merupakan kandungan asam dalam anggur yang tidak terbangun selama fermentasi, dinyatakan dalam satuan gram asam tartaric per liter (g/l).
#
# Volatile Acidity: Merupakan jumlah asam asetat dalam anggur, yang dapat memberikan rasa cuka atau rasa asam yang tidak diinginkan. Dinyatakan dalam satuan gram asam asetat per liter (g/l).
#
# Citric Acid: Merupakan kandungan asam sitrat dalam anggur. Dinyatakan dalam satuan gram asam sitrat per liter (g/l).
#
# Residual Sugar: Merupakan jumlah gula yang tersisa setelah fermentasi selesai. Dinyatakan dalam satuan gram per liter (g/l).
#
# Chlorides: Merupakan jumlah garam dalam anggur. Dinyatakan dalam satuan gram natrium klorida per liter (g/l).
#
# Free Sulfur Dioxide: Merupakan jumlah sulfur dioksida (SO2) yang masih bebas dalam anggur. SO2 digunakan sebagai pengawet dan antioksidan alami dalam anggur. Dinyatakan dalam satuan miligram SO2 per liter (mg/l).
#
# Total Sulfur Dioxide: Merupakan jumlah total SO2 dalam anggur, termasuk SO2 yang masih bebas dan SO2 yang terikat pada senyawa lain. Dinyatakan dalam satuan miligram SO2 per liter (mg/l).
#
# Density: Merupakan berat jenis anggur, dinyatakan dalam satuan gram per mililiter (g/ml).
#
# pH: Merupakan tingkat keasaman atau kebasaan dalam anggur, dalam skala 0-14. Angka pH yang rendah menunjukkan tingkat keasaman yang tinggi.
#
# Sulphates: Merupakan jumlah senyawa sulfat dalam anggur. Dinyatakan dalam satuan gram kalium sulfat per liter (g/l).
#
# Alcohol: Merupakan kandungan alkohol dalam anggur, dinyatakan dalam satuan persen volume (% vol).
#
# Quality: Merupakan penilaian kualitas anggur oleh ahli atau pengamat anggur, dalam skala 0-10. Semakin tinggi nilai kualitas, semakin baik kualitas anggur tersebut.

# %%
import statistics
print("\nKolom            : fixed acidity")
print("Mean             : ",df["fixed acidity"].mean())
print("Min              : ", df["fixed acidity"].min())
print("Max              : ", df["fixed acidity"].max())
print("Standar Deviasi  : ",statistics.stdev(df["fixed acidity"]))

print("\nKolom            : volatile acidity")
print("Mean             : ",df["volatile acidity"].mean())
print("Min              : ", df["volatile acidity"].min())
print("Max              : ", df["volatile acidity"].max())
print("Standar Deviasi  : ",statistics.stdev(df["volatile acidity"]))

print("\nKolom            : citric acid")
print("Mean             : ",df["citric acid"].mean())
print("Min              : ", df["citric acid"].min())
print("Max              : ", df["citric acid"].max())
print("Standar Deviasi  : ",statistics.stdev(df["citric acid"]))

print("\nKolom            : residual sugar")
print("Mean             : ",df["residual sugar"].mean())
print("Min              : ", df["residual sugar"].min())
print("Max              : ", df["residual sugar"].max())
print("Standar Deviasi  : ",statistics.stdev(df["residual sugar"]))

print("\nKolom            : chlorides")
print("Mean             : ",df["chlorides"].mean())
print("Min              : ", df["chlorides"].min())
print("Max              : ", df["chlorides"].max())
print("Standar Deviasi  : ",statistics.stdev(df["chlorides"]))

print("\nKolom            : free sulfur dioxide")
print("Mean             : ",df["free sulfur dioxide"].mean())
print("Min              : ", df["free sulfur dioxide"].min())
print("Max              : ", df["free sulfur dioxide"].max())
print("Standar Deviasi  : ",statistics.stdev(df["free sulfur dioxide"]))

print("\nKolom            : total sulfur dioxide")
print("Mean             : ",df["total sulfur dioxide"].mean())
print("Min              : ", df["total sulfur dioxide"].min())
print("Max              : ", df["total sulfur dioxide"].max())
print("Standar Deviasi  : ",statistics.stdev(df["total sulfur dioxide"]))

print("\nKolom            : density")
print("Mean             : ",df["density"].mean())
print("Min              : ", df["density"].min())
print("Max              : ", df["density"].max())
print("Standar Deviasi  : ",statistics.stdev(df["density"]))

print("\nKolom            : pH")
print("Mean             : ",df["pH"].mean())
print("Min              : ", df["pH"].min())
print("Max              : ", df["pH"].max())
print("Standar Deviasi  : ",statistics.stdev(df["pH"]))

print("\nKolom            : sulphates")
print("Mean             : ",df["sulphates"].mean())
print("Min              : ", df["sulphates"].min())
print("Max              : ", df["sulphates"].max())
print("Standar Deviasi  : ",statistics.stdev(df["sulphates"]))

print("\nKolom            : alcohol")
print("Mean             : ",df["alcohol"].mean())
print("Min              : ", df["alcohol"].min())
print("Max              : ", df["alcohol"].max())
print("Standar Deviasi  : ",statistics.stdev(df["alcohol"]))

print("\nKolom            : quality")
print("Mean             : ",df["quality"].mean())
print("Min              : ", df["quality"].min())
print("Max              : ", df["quality"].max())
print("Standar Deviasi  : ",statistics.stdev(df["quality"]))
# Out:
# Kolom            : fixed acidity
# Mean             :  8.31963727329581
# Min              :  4.6
# Max              :  15.9
# Standar Deviasi  :  1.7410963181276955
#
# Kolom            : volatile acidity
# Mean             :  0.5278205128205128
# Min              :  0.12
# Max              :  1.58
# Standar Deviasi  :  0.1790597041535354
#
# Kolom            : citric acid
# Mean             :  0.2709756097560976
# Min              :  0.0
# Max              :  1.0
# Standar Deviasi  :  0.19480113740531857
#
# Kolom            : residual sugar
# Mean             :  2.53880550343965
# Min              :  0.9
# Max              :  15.5
# Standar Deviasi  :  1.4099280595072798
#
# Kolom            : chlorides
# Mean             :  0.08746654158849279
# Min              :  0.012
# Max              :  0.611
# Standar Deviasi  :  0.047065302010090106
#
# Kolom            : free sulfur dioxide
# Mean             :  15.874921826141339
# Min              :  1.0
# Max              :  72.0
# ...

# %% [markdown]
# ### Explore Data

# %%
import seaborn as sns

# %%
df.hist("quality")
# Out:
# array([[<Axes: title={'center': 'quality'}>]], dtype=object)

# %% [markdown]
# visualisasi diatas menunjukkan histogram dari kolom quality yang memperlihatkan jumlah wine yang memiliki kualitas setiap kelasnya. Kualitas dengan kepemiliki data terbanyak ada pada kualitas 5.

# %%
sns.histplot(x='alcohol', data=df)
# Out:
# <Axes: xlabel='alcohol', ylabel='Count'>

# %% [markdown]
# Visualisasi data diatas menunjukkan data wine dari keseluruhan, sebagian besar memiliki alkohol dengan kadar 9 hingga 11

# %%
sns.heatmap(df.corr(), cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# Pada visualisasi diatas menunjukkan korelasi setiap kolom yang ada pada dataset ini. Setiap warna melambangkan besar tidaknya sebuah hubungan antara kedua kolom, semakin gelap warnanya maka semakin kecil korelasi yang tercipta.

# %%
import matplotlib.pyplot as plt
plt.scatter(df['alcohol'], df['pH'])

# %% [markdown]
# Dari visualisasi diatas menunjukkan bahwa sebagian besar wine memiliki pH dengan range 3.0 hingga 3.6 dan alkohol dari 9 sampai 12

# %% [markdown]
# ## Verify Data Quality

# %% [markdown]
# ## Validity Data
# Data tersebut dapat di uji validitasnya pada link berikut :

# %% [markdown]
# ##Duplicate Data

# %%
is_duplicated = df.duplicated().any()

print("Status Duplikasi :",is_duplicated)
# Out:
# Status Duplikasi : True

# %% [markdown]
# Menyatakan hasil uji diplikasi bernilai false. Artinya data tersebut layak untuk digunakan

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Select Data

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# ### Transform Data

# %% [markdown]
# ### Menampilkan Jumlah Data dalam Kolom dengan Data Kosong

# %%
df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ### Slicing Data

# %%
slicing_data = df

# %%
slicing_data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# ### Data Reduction

# %%
data = slicing_data.drop(columns=["residual sugar"])
data = data.drop(columns=["density"])

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  chlorides  \
# 0               7.4             0.700         0.00      0.076
# 1               7.8             0.880         0.00      0.098
# 2               7.8             0.760         0.04      0.092
# 3              11.2             0.280         0.56      0.075
# 4               7.4             0.700         0.00      0.076
# ...             ...               ...          ...        ...
# 1594            6.2             0.600         0.08      0.090
# 1595            5.9             0.550         0.10      0.062
# 1596            6.3             0.510         0.13      0.076
# 1597            5.9             0.645         0.12      0.075
# 1598            6.0             0.310         0.47      0.067
#
#       free sulfur dioxide  total sulfur dioxide    pH  sulphates  alcohol  \
# 0                    11.0                  34.0  3.51       0.56      9.4
# ...

# %% [markdown]
# Melakukan Pengkategorian beberapa kolom untuk menampilkan baris yang memenuhi kategori yang diinginkan

# %%
data = data[data["quality"]>=data["quality"].mean()]

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  chlorides  \
# 3              11.2              0.28         0.56      0.075
# 7               7.3              0.65         0.00      0.065
# 8               7.8              0.58         0.02      0.073
# 16              8.5              0.28         0.56      0.092
# 19              7.9              0.32         0.51      0.341
# ...             ...               ...          ...        ...
# 1592            6.3              0.51         0.13      0.076
# 1593            6.8              0.62         0.08      0.068
# 1595            5.9              0.55         0.10      0.062
# 1596            6.3              0.51         0.13      0.076
# 1598            6.0              0.31         0.47      0.067
#
#       free sulfur dioxide  total sulfur dioxide    pH  sulphates  alcohol  \
# 3                    17.0                  60.0  3.16       0.58      9.8
# ...

# %% [markdown]
# ## MODELLING

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score,calinski_harabasz_score,davies_bouldin_score
from sklearn.preprocessing import StandardScaler
import time
import plotly.subplots as sp
import plotly.graph_objs as go
import plotly.express as px

# %% [markdown]
# #Pre-processing

# %%
train = pd.get_dummies(data)

# %%
scaler = StandardScaler()

scaled_data = scaler.fit_transform(train)

# %%
import warnings
warnings.filterwarnings("ignore")
elbow_scores = []
k_range = range(2, 10)
for k in k_range:
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(train)
    elbow_scores.append(kmeans.inertia_)

plt.plot(k_range, elbow_scores,"bx-")
plt.xlabel('Jumlah Kluster (K)')
plt.ylabel('WCSS')
plt.title('Elbow Method')
plt.show()

# %%
class Kmeans:
    """The k-means algorithm."""

    def __init__(self, n_clusters):
        self.data = pd.DataFrame()
        self.n_clusters = n_clusters
        self.centroids = pd.DataFrame()
        self.clusters = np.ndarray(1)
        self.old_centroids = pd.DataFrame()
        self.verbose = False
        self.predictions = list()

    def train(self, df, verbose):
        self.verbose = verbose
        self.data = df.copy(deep=True)
        self.clusters = np.zeros(len(self.data))

        if 'species' in self.data.columns:
            self.data.drop('species', axis=1, inplace=True)

        # Randomly initialize centroids
        unique_rows = self.data.drop_duplicates()
        unique_rows.reset_index(drop=True, inplace=True)
        self.centroids = unique_rows.sample(n=self.n_clusters)
        self.centroids.reset_index(drop=True, inplace=True)

        if self.verbose:
            print("\nRandomly initiated centroids:")
            print(self.centroids)

        # Initialize old centroids as a matrix of all 0's
        self.old_centroids = pd.DataFrame(np.zeros(shape=(self.n_clusters, self.data.shape[1])),
                                          columns=self.data.columns)

        # Compare every data point in our dataset to each of the k-means and assign each point to closest cluster
        while not self.old_centroids.equals(self.centroids):
            
            if self.verbose:
                time.sleep(3)

            # Stash old centroids
            self.old_centroids = self.centroids.copy(deep=True)

            # Iterate through each data point in the matrix
            for row_i in range(0, len(self.data)):
                distances = list()
                point = self.data.iloc[row_i]

                # Calculate the distance between the current point and each of the centroids
                for row_c in range(0, len(self.centroids)):
                    centroid = self.centroids.iloc[row_c]
                    distances.append(np.linalg.norm(point - centroid))

                # Assign this data point to a cluster
                self.clusters[row_i] = np.argmin(distances)

            # For each cluster extract the values which now belong to each cluster and calculate new k-means
            for cls in range(0, self.n_clusters):

                cls_idx = np.where(self.clusters == cls)[0]

                if len(cls_idx) == 0:
                    self.centroids.loc[cls] = self.old_centroids.loc[cls]
                else:
                    # Set the new k-mean to the mean value of the data points within this cluster
                    self.centroids.loc[cls] = self.data.iloc[cls_idx].mean()
                    
                if self.verbose:
                    print("\nRow indices belonging to cluster {}: [n={}]".format(cls, len(cls_idx)))
                    print(cls_idx)

            if self.verbose:
                print("\nOld centroids:")
                print(self.old_centroids)
                print("New centroids:")
                print(self.centroids)

# %%
number_of_clusters = 3
kmeans = Kmeans(n_clusters=number_of_clusters)
kmeans.train(df=train, verbose=False)

# %%
# Extract the results
train['cluster'] = kmeans.clusters
centroids = kmeans.centroids
centroids['cluster'] = 'centroid'
all_df = pd.concat([train, centroids])

# %%
all_df
# Out:
#       fixed acidity  volatile acidity  citric acid  chlorides  \
# 3         11.200000          0.280000     0.560000   0.075000
# 7          7.300000          0.650000     0.000000   0.065000
# 8          7.800000          0.580000     0.020000   0.073000
# 16         8.500000          0.280000     0.560000   0.092000
# 19         7.900000          0.320000     0.510000   0.341000
# ...             ...               ...          ...        ...
# 1596       6.300000          0.510000     0.130000   0.076000
# 1598       6.000000          0.310000     0.470000   0.067000
# 0          7.689011          0.513516     0.290879   0.079582
# 1          8.323411          0.481405     0.277124   0.082736
# 2          8.724516          0.461774     0.316280   0.083215
#
#       free sulfur dioxide  total sulfur dioxide        pH  sulphates  \
# 3               17.000000             60.000000  3.160000   0.580000
# 7               15.000000             21.000000  3.390000   0.470000
# ...

# %%
def plot_cluster(cluster_df):
    plot, ax = plt.subplots(3,6,figsize=(25,15),constrained_layout = True)
    cols = ['fixed acidity', 'volatile acidity', 'total sulfur dioxide', 'sulphates', 'free sulfur dioxide', 'pH']
    sns.countplot(data=cluster_df,x="fixed acidity",ax=ax[2][2])
    sns.histplot(data=cluster_df,x="volatile acidity",ax=ax[2][3])
    sns.countplot(data=cluster_df,x="citric acid",ax=ax[2][2])
    sns.countplot(data=cluster_df,x="chlorides",ax=ax[2][2])
    sns.countplot(data=cluster_df,x="free sulfur dioxide",ax=ax[2][2])
    sns.countplot(data=cluster_df,x="total sulfur dioxide",ax=ax[2][2])
    sns.countplot(data=cluster_df,x="pH",ax=ax[2][2])
    sns.countplot(data=cluster_df,x="sulphates",ax=ax[2][2])
    sns.countplot(data=cluster_df,x="alcohol",ax=ax[2][2])
    sns.countplot(data=cluster_df,x="quality",ax=ax[2][2])
    for i,col in enumerate(cols):
        sns.histplot(data=cluster_df,x=col,ax=ax[0][i],kde=True)
        sns.boxplot(data=cluster_df,x=col,ax=ax[1][i])

# %%
cluster1 = train[train['cluster'] == 0]
cluster2 = train[train['cluster'] == 1]
cluster3 = train[train['cluster'] == 2]

# %%
cluster1
# Out:
#       fixed acidity  volatile acidity  citric acid  chlorides  \
# 16              8.5             0.280         0.56      0.092
# 33              6.9             0.605         0.12      0.073
# 54              7.6             0.510         0.15      0.110
# 86              8.6             0.490         0.28      0.110
# 91              8.6             0.490         0.28      0.110
# ...             ...               ...          ...        ...
# 1456            6.0             0.540         0.06      0.050
# 1475            5.3             0.470         0.11      0.048
# 1477            5.3             0.470         0.11      0.048
# 1574            5.6             0.310         0.78      0.074
# 1588            7.2             0.660         0.33      0.068
#
#       free sulfur dioxide  total sulfur dioxide    pH  sulphates    alcohol  \
# 16                   35.0                 103.0  3.30       0.75  10.500000
# ...

# %%
cluster1.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  chlorides  \
# count      91.000000         91.000000    91.000000  91.000000
# mean        7.689011          0.513516     0.290879   0.079582
# std         1.578709          0.180871     0.182706   0.040098
# min         4.700000          0.180000     0.000000   0.012000
# 25%         6.850000          0.375000     0.180000   0.062500
# 50%         7.700000          0.520000     0.270000   0.078000
# 75%         8.500000          0.620000     0.370000   0.086000
# max        12.400000          1.020000     0.780000   0.337000
#
#        free sulfur dioxide  total sulfur dioxide         pH  sulphates  \
# count            91.000000             91.000000  91.000000  91.000000
# mean             26.884615             96.307692   3.303407   0.701978
# std              12.545268             33.737777   0.191695   0.266409
# min               5.000000             70.000000   2.870000   0.390000
# ...

# %%
plot_cluster(cluster1)

# %% [markdown]
# Dari Visualiasi dan describe diatas pada cluster 1 menunjukkan bahwa dominasi data diisi oleh data dengan nilai yang cukup tinggi. Terlihat pada visualisasi total sulfur dan free sulfur menunjukkan nilai  puluhan hingga ratusan. Range yang ada pada dataset ini juga menunjukkan range yang cukup tinggi.

# %%
cluster2
# Out:
#       fixed acidity  volatile acidity  citric acid  chlorides  \
# 3              11.2             0.280         0.56      0.075
# 19              7.9             0.320         0.51      0.341
# 20              8.9             0.220         0.48      0.077
# 24              6.9             0.400         0.14      0.085
# 31              6.9             0.685         0.00      0.105
# ...             ...               ...          ...        ...
# 1592            6.3             0.510         0.13      0.076
# 1593            6.8             0.620         0.08      0.068
# 1595            5.9             0.550         0.10      0.062
# 1596            6.3             0.510         0.13      0.076
# 1598            6.0             0.310         0.47      0.067
#
#       free sulfur dioxide  total sulfur dioxide    pH  sulphates  alcohol  \
# 3                    17.0                  60.0  3.16       0.58      9.8
# ...

# %%
cluster2.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid   chlorides  \
# count     299.000000        299.000000   299.000000  299.000000
# mean        8.323411          0.481405     0.277124    0.082736
# std         1.878862          0.146442     0.191235    0.033437
# min         4.900000          0.160000     0.000000    0.034000
# 25%         7.000000          0.360000     0.100000    0.069000
# 50%         7.900000          0.450000     0.290000    0.079000
# 75%         9.300000          0.585000     0.415000    0.089000
# max        15.600000          0.910000     0.760000    0.414000
#
#        free sulfur dioxide  total sulfur dioxide          pH   sulphates  \
# count           299.000000            299.000000  299.000000  299.000000
# mean             21.526756             49.745819    3.338395    0.698294
# std               8.413054              9.767547    0.157389    0.134277
# min               1.000000             33.000000    2.900000    0.430000
# ...

# %%
plot_cluster(cluster2)

# %% [markdown]
# Berbeda dengan kluster 1 yang berisi dengan data yang dominan nilainya besar, pada cluster 2 diisi dengan data yang berada sebagian besar di tengah-tengah. Terlihat range yang diberikan masih berada dibawah range cluster 1. Kemudian persebaran nilainya juga relatif cukup merata berbeda dengan cluster 1 yang beberapa nilainya didominasi oleh beberapa.

# %%
cluster3
# Out:
#       fixed acidity  volatile acidity  citric acid  chlorides  \
# 7               7.3             0.650         0.00      0.065
# 8               7.8             0.580         0.02      0.073
# 29              7.8             0.645         0.00      0.082
# 35              7.8             0.645         0.00      0.086
# 36              7.8             0.600         0.14      0.086
# ...             ...               ...          ...        ...
# 1577            6.2             0.700         0.15      0.076
# 1578            6.8             0.670         0.15      0.118
# 1580            7.4             0.350         0.33      0.068
# 1587            5.8             0.610         0.11      0.066
# 1591            5.4             0.740         0.09      0.089
#
#       free sulfur dioxide  total sulfur dioxide    pH  sulphates  alcohol  \
# 7                    15.0                  21.0  3.39       0.47     10.0
# ...

# %%
cluster3.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid   chlorides  \
# count     465.000000        465.000000   465.000000  465.000000
# mean        8.724516          0.461774     0.316280    0.083215
# std         1.854085          0.166410     0.207262    0.039025
# min         5.200000          0.120000     0.000000    0.038000
# 25%         7.200000          0.330000     0.110000    0.066000
# 50%         8.300000          0.440000     0.350000    0.075000
# 75%        10.100000          0.570000     0.480000    0.086000
# max        15.000000          1.040000     0.760000    0.415000
#
#        free sulfur dioxide  total sulfur dioxide          pH   sulphates  \
# count           465.000000            465.000000  465.000000  465.000000
# mean              8.978495             21.522581    3.294215    0.687140
# std               4.258811              7.783439    0.141952    0.138286
# min               1.000000              6.000000    2.860000    0.400000
# ...

# %%
plot_cluster(cluster3)

# %% [markdown]
# Cluster 3 tidak jauh berbeda dengan cluster sebelumnya, hanya saja untuk nilai total sulfur dan free sulfur diisi data yang bernilai lebih kecil dibanding kedua cluster sebelumnya. Hal ini bisa dilihat bahwa range yang ditampilkan dimulai dari satuan dan hanya hingga puluhan saja. Namun terlihat perbedaan pada visualisasi yang menampilkan kualitas dari wine tersebut dimana quality bernilai 7 jauh lebih banyak ditemukan pada cluster ini.

# %%
px.scatter_3d(all_df, x='fixed acidity', y='total sulfur dioxide', z='sulphates', color='cluster',color_continuous_scale=['#ADFF2F', '#19A3E8', '#FF5A44', '#FFD326'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.scatter_3d(all_df, x='volatile acidity', y='pH', z='sulphates', color='cluster',color_continuous_scale=['#ADFF2F', '#19A3E8', '#FF5A44', '#FFD326'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### EVALUATION

# %%
# Menghitung nilai Silhouette Score
silhouette_avg = silhouette_score(train.drop('cluster', axis=1), kmeans.clusters)

# Menghitung nilai Calinski-Harabasz Index
ch_score= calinski_harabasz_score(train.drop('cluster', axis=1), kmeans.clusters)

# Menghitung nilai Davies-Bouldin Index
db_score= davies_bouldin_score(train.drop('cluster', axis=1), kmeans.clusters)

# Create dataframe for metrics and scores
metrics = ["Silhouette Score", "Calinski-Harabasz Score", "Davies-Bouldin Score"]
scores = [silhouette_avg, ch_score, db_score]
df_scores = pd.DataFrame({'Metric': metrics, 'Score': scores})

# reset index dataframe
df_scores = df_scores.reset_index(drop=True)

# ubah nama axis pada index dan kolom
df_scores = df_scores.rename_axis('', axis=0).rename_axis('Metrics', axis=1)

# Display dataframe as table without index column
display(df_scores.style.hide_index())
# Out:
# <style type="text/css">
# </style>
# <table id="T_cb972" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_cb972_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_cb972_level0_col1" class="col_heading level0 col1" >Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cb972_row0_col0" class="data row0 col0" >Silhouette Score</td>
#       <td id="T_cb972_row0_col1" class="data row0 col1" >0.514704</td>
#     </tr>
#     <tr>
#       <td id="T_cb972_row1_col0" class="data row1 col0" >Calinski-Harabasz Score</td>
#       <td id="T_cb972_row1_col1" class="data row1 col1" >1066.300950</td>
#     </tr>
#     <tr>
#       <td id="T_cb972_row2_col0" class="data row2 col0" >Davies-Bouldin Score</td>
#       <td id="T_cb972_row2_col1" class="data row2 col1" >0.711280</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Evaluasi metrik diatas menunjukkan bahwa clustering yang dilakukan pada dataset wine quality menghasilkan hasil yang baik.
# 1. Nilai silhouette score yang positif menunjukkan bahwa kluster memiliki pemisahan yang moderat
# 2. skor Calinski-Harabasz yang tinggi menunjukkan pembagian kluster yang baik dan padat
# 3. dan skor Davies-Bouldin yang rendah menunjukkan adanya pemisahan yang baik antara kluster dan jarak yang cukup antara kluster.

# %% [markdown]
# ### DEPLOYMENT

# %%
all_df.to_csv('new_winequality - Deployment.csv')

# %% [markdown]
# ## Kesimpulan
